# %%
import numpy as np
x = np.arange(0,100)
y=x*2
z=x**2

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# create a figure object called fig using plt.figure()
#
# Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this as new axis ax.
#
# Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
plt.plot(x,y)
plt.title('title')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0,0.5,'y')

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### Create a figure object and put two axes on it, ax1 and ax2, Located at [0,0,1,1] and [0.2,0.5,.2,.2]repectively

# %%
fig1 = plt.figure()
ax1=fig1.add_axes([0,0,1,1])
ax2=fig1.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# ### Now plot(x,y) on both axes. And call your figure object to show it

# %%
fig1 = plt.figure(figsize=(18,10))
ax1=fig1.add_axes([0,0,1,1])
ax2=fig1.add_axes([0.2,0.5,0.2,0.2])
ax1.plot(x,y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax2.plot(x,y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
plt.show()

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### Create the below plot by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]

# %%
fig=plt.figure(figsize=(18,10))
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,.4,.4])

# %% [markdown]
# ### Now user x,y and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot

# %%
fig=plt.figure(figsize=(18,10))
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,.4,.4])
ax1.plot(x,z)
ax1.set_xlabel('X')
ax1.set_ylabel('Z')
ax2.plot(x,y)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_xlim(20.0,22.0)
ax2.set_ylim(30,50)
ax2.set_title('zoom')
# Out:
# Text(0.5,1,'zoom')

# %%
fig=plt.figure(figsize=(18,10))
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,.4,.4])
ax1.plot(x,z)
ax1.set_xlabel('X')
ax1.set_ylabel('Z')
ax2.plot(x,y)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_xlim(20.0,22.0)
ax2.set_ylim(30,50)
ax2.set_title('zoom')
# Out:
# Text(0.5,1,'zoom')

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ### Use plt.subplots(nrows=1,ncols=2) to create below plot

# %%
fig=plt.subplots(nrows=1,ncols=2)

# %% [markdown]
# ### Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y,color='blue',lw=5,ls="--")
axes[1].plot(x,z,color='red',lw=3)

# %% [markdown]
# ### See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(18,5))

axes[0].plot(x,y,color='blue',lw=5)
axes[1].plot(x,z,color='red',lw=3,ls='--')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('Z')
# Out:
# Text(0,0.5,'Z')
